# %%
# !pip install selenium
# !pip install chromedriver_binary

# %%
from selenium import webdriver
import chromedriver_binary
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
browser = webdriver.Edge()

# %%
data = []
for i in range(1,50):
    print( "https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=83ab62dc-0a8c-4273-9905-347ac5d26ca2&page="+ str(i))
    res = browser.get(link)
    soup = BeautifulSoup(browser.page_source , "html.parser")
    
    for sp in soup.find_all("div" , class_ = "tUxRFH"):
        try:
            mobile_name = sp.find("div" , class_ = "KzDlHZ")
        except:
            print(np.nan)
        try:
            
            rating = sp.find("div" , class_ = "XQDdHH")
        except:
            print(np.nan)

    #     total_ratings = sp.find("div" , class_ = "_5OesEi").find_all("span")[3]
    #     total_reviews = sp.find("div" , class_ = "_5OesEi").find_all("span")[5]
        RAM_and_ROM = sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[0]
        size = sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[1]
        cemera = sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[2]
        battery= sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[3]
        processor= sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[4]
#         warranty= sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[5]
        price = sp.find("div" , class_ = "Nx9bqj _4b5DiR")
        discount = sp.find("div" , class_ = "UkUFwK").find("span")
        mobile_link = sp.find("a" , class_ = "CGtC98").get("href")
        delevery_type = sp.find("div" , class_ = "yiggsN")
        mobile_pic = sp.find("img" , class_ = "DByuf4").get("src")
        data.append([mobile_name, rating, RAM_and_ROM, size, cemera, battery, processor, price, discount, mobile_link, delevery_type, mobile_pic])
        df = pd.DataFrame(data , columns = ["mobile_name" , "rating", "RAM_and_ROM" , "size" , "cemera" , "battery" , "processor" , "price", "discount" ,"mobile_link", "delevery_type" ,"mobile_pic"])
# Out:
# https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=83ab62dc-0a8c-4273-9905-347ac5d26ca2&page=1
# https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=83ab62dc-0a8c-4273-9905-347ac5d26ca2&page=2
# https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=83ab62dc-0a8c-4273-9905-347ac5d26ca2&page=3
# ...

# %%
df
# Out:
#                                            mobile_name     rating  \
# 0    [Motorola Edge 50 Fusion (Marshmallow Blue, 25...  [4.4, []]
# 1              [Motorola G85 5G (Cobalt Blue, 128 GB)]  [4.4, []]
# 2           [vivo T3 Lite 5G (Majestic Black, 128 GB)]  [4.4, []]
# 3           [vivo T3 Lite 5G (Majestic Black, 128 GB)]  [4.3, []]
# 4            [vivo T3 Lite 5G (Vibrant Green, 128 GB)]  [4.4, []]
# ..                                                 ...        ...
# 235  [OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 12...  [4.4, []]
# 236  [OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)]  [4.4, []]
# 237  [OPPO K12x 5G with 45W SUPERVOOC Charger In-Th...  [4.5, []]
# 238  [OPPO K12x 5G with 45W SUPERVOOC Charger In-Th...  [4.5, []]
# 239             [Motorola G85 5G (Urban Grey, 256 GB)]  [4.4, []]
#
#                                         RAM_and_ROM  \
# 0                          [12 GB RAM | 256 GB ROM]
# 1                           [8 GB RAM | 128 GB ROM]
# ...

# %%
data = []
for sp in soup.find_all("div" , class_ = "tUxRFH"):
        mobile_name = sp.find("div" , class_ = "KzDlHZ")
        rating = sp.find("div" , class_ = "XQDdHH")

    #     total_ratings = sp.find("div" , class_ = "_5OesEi").find_all("span")[3]
    #     total_reviews = sp.find("div" , class_ = "_5OesEi").find_all("span")[5]
        RAM_and_ROM = sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[0]
        size = sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[1]
        cemera = sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[2]
        battery= sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[3]
        processor= sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[4]
#         warranty= sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[5]
        price = sp.find("div" , class_ = "Nx9bqj _4b5DiR")
        discount = sp.find("div" , class_ = "UkUFwK").find("span")
        mobile_link = sp.find("a" , class_ = "CGtC98").get("href")
        delevery_type = sp.find("div" , class_ = "yiggsN")
        mobile_pic = sp.find("img" , class_ = "DByuf4").get("src")
        data.append([mobile_name, rating, RAM_and_ROM, size, cemera, battery, processor, price, discount, mobile_link, delevery_type, mobile_pic])

# %%
df = pd.DataFrame(data , columns = ["mobile_name" , "rating", "RAM_and_ROM" , "size" , "cemera" , "battery" , "processor" , "price", "discount" ,"mobile_link", "delevery_type" ,"mobile_pic"])

# %%
df
# Out:
#                                           mobile_name     rating  \
# 0            [vivo T3 Pro 5G (Emerald Green, 128 GB)]  [4.5, []]
# 1   [Tecno Spark 20 Pro 5G (Startrail Black, 256 GB)]  [3.8, []]
# 2                   [POCO C65 (Pastel Green, 128 GB)]  [4.3, []]
# 3               [REDMI 13C (Starshine Green, 128 GB)]  [4.2, []]
# 4   [itel Power 450 | 2.4 inch Big Display | 2500 ...  [4.1, []]
# 5   [itel it2175 Pro | 2 inch Big Display | 1200 m...    [4, []]
# 6           [vivo T3 Lite 5G (Vibrant Green, 128 GB)]  [4.4, []]
# 7   [POCO C61  - Locked with Airtel Prepaid (Mysti...  [4.2, []]
# 8                                           [Vox V17]  [3.6, []]
# 9                    [POCO C65 (Matte Black, 128 GB)]  [4.2, []]
# 10                   [POCO C65 (Pastel Blue, 128 GB)]  [4.3, []]
# 11                   [POCO C65 (Pastel Blue, 128 GB)]  [4.2, []]
# 12              [REDMI 13C (Starfrost White, 128 GB)]  [4.2, []]
# ...

# %%
df.isnull().sum()
# Out:
# mobile_name      0
# rating           0
# RAM_and_ROM      0
# size             0
# cemera           0
# battery          0
# processor        0
# price            0
# discount         0
# mobile_link      0
# delevery_type    0
# mobile_pic       0
# dtype: int64

# %%
data = []

for sp in soup.find_all("div" , class_ = "tUxRFH"):
    mobile_name = sp.find("div" , class_ = "KzDlHZ")
    rating = sp.find("div" , class_ = "XQDdHH")
        
#     total_ratings = sp.find("div" , class_ = "_5OesEi").find_all("span")[3]
#     total_reviews = sp.find("div" , class_ = "_5OesEi").find_all("span")[5]
    RAM_and_ROM = sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[0]
    size = sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[1]
    cemera = sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[2]
    battery= sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[3]
    processor= sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[4]
    warranty= sp.find("ul" , class_ = "G4BRas").find_all("li", class_ = "J+igdf")[5]
    price = sp.find("div" , class_ = "Nx9bqj _4b5DiR")
    discount = sp.find("div" , class_ = "UkUFwK").find("span")
    mobile_link = sp.find("a" , class_ = "CGtC98").get("href")
    delevery_type = sp.find("div" , class_ = "yiggsN")
    mobile_pic = sp.find("img" , class_ = "DByuf4").get("src")
    data.append([mobile_name, rating, RAM_and_ROM , cemera, processor , battery , processor ,warranty, price ,discount, mobile_link, delevery_type,mobile_pic])
    df_2 = pd.DataFrame(data_2 , columns = ["mobile_name" , "rating", "RAM_and_ROM" , "size" , "cemera" , "battery" , "processor" , "price", "discount" ,"mobile_link", "delevery_type" ,"mobile_pic"])

# %%
df
# Out:
#                                           mobile_name     rating  \
# 0            [vivo T3 Pro 5G (Emerald Green, 128 GB)]  [4.5, []]
# 1   [Tecno Spark 20 Pro 5G (Startrail Black, 256 GB)]  [3.8, []]
# 2                   [POCO C65 (Pastel Green, 128 GB)]  [4.3, []]
# 3               [REDMI 13C (Starshine Green, 128 GB)]  [4.2, []]
# 4   [itel Power 450 | 2.4 inch Big Display | 2500 ...  [4.1, []]
# 5   [itel it2175 Pro | 2 inch Big Display | 1200 m...    [4, []]
# 6           [vivo T3 Lite 5G (Vibrant Green, 128 GB)]  [4.4, []]
# 7   [POCO C61  - Locked with Airtel Prepaid (Mysti...  [4.2, []]
# 8                                           [Vox V17]  [3.6, []]
# 9                    [POCO C65 (Matte Black, 128 GB)]  [4.2, []]
# 10                   [POCO C65 (Pastel Blue, 128 GB)]  [4.3, []]
# 11                   [POCO C65 (Pastel Blue, 128 GB)]  [4.2, []]
# 12              [REDMI 13C (Starfrost White, 128 GB)]  [4.2, []]
# ...

# %%
df.to_csv("flipcart_mobile_data_scrap.csv")
